# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('Consumption_Emissions.csv')

# %%
df = df[['col_0','Canada']]

# %%
df.rename(columns={"col_0": "Year"}, inplace = True)
df.head(5)
# Out:
#    Year  Canada
# 0  1959     NaN
# 1  1960     NaN
# 2  1961     NaN
# 3  1962     NaN
# 4  1963     NaN

# %%
df = df.dropna()
df.head(5)
# Out:
#     Year  Canada
# 31  1990   133.0
# 32  1991   132.0
# 33  1992   136.0
# 34  1993   133.0
# 35  1994   134.0

# %%
plt.scatter(df['Year'],df['Canada'])

# %%
m, c = np.poly1d(np.polyfit(df['Year'],, 1))

# %%
x = df['Year']
y = df['Canada']
# Out:
# 0.9828698553948784 -1819.2959584723667

# %%
y = m*df['Year']s = UnivariateSpline(x, y, s=5)
xs = np.linspace(0, 29, 100)
ys = s(xs) + c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_61/1923701838.py in <module>
# ----> 1 y = m*x + c
#
# NameError: name 'x' is not defined
